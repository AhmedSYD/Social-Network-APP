# %%
from collections import OrderedDict
import json 
from tkinter import *
from tkinter.ttk import Combobox
from tkinter import scrolledtext

# %%
class Person:
    def __init__(self,personID=None,firstName=None,surname=None,age=None,gender=None,friends=None):
        self.id=personID
        self.firstName=firstName
        self.surname=surname
        self.age=age
        self.gender=gender
        self.friends=friends
        
    def set_id(self,personID):
        self.id=personID     
    def get_id(self):
        return self.id
    
    def set_firstName(self,firstName):
        self.firstName=firstName     
    def get_firstName(self):
        return self.firstName
    
    def set_surname(self,surname):
        self.surname=surname     
    def get_surname(self):
        return self.surname
    
    def set_age(self,age):
        self.age=age     
    def get_age(self):
        return self.age
    
    def set_gender(self,gender):
        self.gender=gender    
    def get_gender(self):
        return self.gender
    
    def set_friends(self,friends):
        self.friends=friends     
    def get_friends(self):
        return self.friends

# %%
class ProcssData():
    def __init__(self,jsonFilePath=None):
        self.hashTable={} ##self.hashTable is hash table attribute ,which its index is person id and value is person object
        self.lenDataInHashTable=0
        if(not(jsonFilePath==None)):
            self.read_and_process_jsonFile(jsonFilePath)

    ##read data from path of json file and return list of data
    def load_json_data(self,jsonFilePath):
        loadedData=[]
        try:
            jsonData=open(jsonFilePath, 'r')
            loadedData= json.load(jsonData) ## loadedData is list of all json data
        except IOError:
            print("File not accessible")

        return loadedData
    
    ##get list of data from json file as an input and put into hash table 
    def put_data_into_hashTable(self,loadedData):
        for obj in loadedData:
            print("id:",obj["id"])
            print("firstName:",obj["firstName"])
            print("surname:",obj["surname"])
            print("age:",obj["age"])
            print("gender:",obj["gender"])
            print("friends:",obj["friends"])
            personObject=Person(personID=obj["id"],firstName=obj["firstName"],surname=obj["surname"],age=obj["age"],\
                   gender=obj["gender"],friends=obj["friends"])
            self.hashTable[obj["id"]]=personObject
            self.lenDataInHashTable+=1
        print(self.hashTable)
        
    ##get no of data recognized in hash table 
    def get_length_of_hashTable(self):
        return self.lenDataInHashTable
        
    ##read json file and extract data from it then put the data into hash table     
    def read_and_process_jsonFile(self,jsonFilePath):
        loadedData=self.load_json_data(jsonFilePath)
        if(len(loadedData)!=0):
            self.put_data_into_hashTable(loadedData)
    
    ##return person object;given its id 
    def get_person_from_id(self,chosenID):
        return self.hashTable[chosenID]  
    
    ##return direct friends for chosen user; given its id
    def get_direct_friends(self,chosenID):
        print("direct_friends of friend(",chosenID,")=",self.hashTable[chosenID].get_friends())
        return self.hashTable[chosenID].get_friends() ##return list of ids of friends
    
    ##return list of friends of friends for chosen_user; given its id
    def get_friends_of_friends(self,chosenID):
        friendsOfFriends=[]
        directFriendsIDs=self.get_direct_friends(chosenID)
        for directFriendID in directFriendsIDs:
            print("for friend id:",directFriendID)
            friendsOfDirectFriendIDs=self.get_direct_friends(directFriendID)
            print("friends of direct friend ids:",friendsOfDirectFriendIDs)
            friendsOfFriends+=friendsOfDirectFriendIDs
            print("============")
        print("friendsOfFriends before remove repeated:",friendsOfFriends)
        return list(OrderedDict.fromkeys(friendsOfFriends)) ##remove repeated id in friendsOfFriends list if found
    
    ##return suggested friends for chosen user; given its id
    def get_suggested_friends(self,chosenID):
        suggestedFriends=[] ##list of all suggested friend
        countRepeatedId=[0]*21 # create list ,every index in it represent person id, to count all id getten    
        directFriendsIDs=self.get_direct_friends(chosenID)
        for directFriendID in directFriendsIDs:
            print("for direct friend id:",directFriendID)
            friendsOfDirectFriendIDs=self.get_direct_friends(directFriendID)
            print("friends_of_direct_friend_id:",friendsOfDirectFriendIDs)
            for friendOfDirectFriendID in friendsOfDirectFriendIDs:
                countRepeatedId[friendOfDirectFriendID]+=1

        print("ccountRepeatedId=",countRepeatedId)
        for selectedID in range(len(countRepeatedId)):
            if(not(selectedID==chosenID) and not(selectedID in directFriendsIDs) and countRepeatedId[selectedID]>1):
                suggestedFriends.append(selectedID)

        return list(OrderedDict.fromkeys(suggestedFriends)) ##remove repeated id in suggestedFriends list if found

# %%
per=Person(personID=2,firstName="ahmed",surname="sayed",age=24,gender="male",friends=[2,3])

# %%
obj=ProcssData("data.json")
obj.get_length_of_hashTable()
# Out:
# id: 1
# firstName: Paul
# surname: Crowe
# age: 28
# gender: male
# friends: [2]
# id: 2
# firstName: Rob
# surname: Fitz
# age: 23
# gender: male
# friends: [1, 3]
# id: 3
# firstName: Ben
# surname: O'Carolan
# age: None
# gender: male
# friends: [2, 4, 5, 7]
# id: 4
# firstName: Victor
# surname:
# age: 28
# gender: male
# friends: [3]
# id: 5
# firstName: Peter
# surname: Mac
# age: 29
# gender: male
# friends: [3, 6, 11, 10, 7]
# id: 6
# firstName: John
# surname: Barry
# age: 18
# gender: male
# friends: [5]
# id: 7
# firstName: Sarah
# surname: Lane
# age: 30
# gender: female
# friends: [3, 5, 20, 12, 8]
# id: 8
# firstName: Susan
# surname: Downe
# age: 28
# gender: female
# friends: [7]
# id: 9
# firstName: Jack
# surname: Stam
# age: 28
# gender: male
# friends: [12]
# id: 10
# firstName: Amy
# surname: Lane
# age: 24
# gender: female
# friends: [5, 11]
# id: 11
# firstName: Sandra
# surname: Phelan
# age: 28
# gender: female
# friends: [5, 10, 19, 20]
# id: 12
# firstName: Laura
# surname: Murphy
# age: 33
# gender: female
# friends: [7, 9, 13, 20]
# id: 13
# firstName: Lisa
# surname: Daly
# age: 28
# gender: female
# friends: [12, 14, 20]
# id: 14
# firstName: Mark
# surname: Johnson
# age: 28
# gender: male
# friends: [13, 15]
# id: 15
# firstName: Seamus
# surname: Crowe
# age: 24
# gender: male
# friends: [14]
# id: 16
# firstName: Daren
# surname: Slater
# age: 28
# gender: male
# friends: [18, 20]
# id: 17
# firstName: Dara
# surname: Zoltan
# age: 48
# gender: male
# friends: [18, 20]
# id: 18
# firstName: Marie
# surname: D
# age: 28
# gender: female
# friends: [17]
# id: 19
# firstName: Catriona
# surname: Long
# age: 28
# gender: female
# friends: [11, 20]
# id: 20
# firstName: Katy
# surname: Couch
# age: 28
# gender: female
# friends: [7, 11, 12, 13, 16, 17, 19]
# {1: <__main__.Person object at 0x000000AD68E3CDD8>, 2: <__main__.Person object at 0x000000AD68E525C0>, 3: <__main__.Person object at 0x000000AD68E4C400>, 4: <__main__.Person object at 0x000000AD68E3CB70>, 5: <__main__.Person object at 0x000000AD68E28208>, 6: <__main__.Person object at 0x000000AD68E39898>, 7: <__main__.Person object at 0x000000AD68E39320>, 8: <__main__.Person object at 0x000000AD68E32DA0>, 9: <__main__.Person object at 0x000000AD68E32978>, 10: <__main__.Person object at 0x000000AD68E32630>, 11: <__main__.Person object at 0x000000AD68E2E518>, 12: <__main__.Person object at 0x000000AD68E22F98>, 13: <__main__.Person object at 0x000000AD68E22B00>, 14: <__main__.Person object at 0x000000AD68E1D2B0>, 15: <__main__.Person object at 0x000000AD68E1D8D0>, 16: <__main__.Person object at 0x000000AD68E3C400>, 17: <__main__.Person object at 0x000000AD68E17080>, 18: <__main__.Person object at 0x000000AD68E13A58>, 19: <__main__.Person object at 0x000000AD68CBBC88>, 20: <__main__.Person object at 0x000000AD68CBB550>}
# 20

# %%
print(per.get_id())
print(per.get_firstName())
print(per.get_surname())
print(per.get_age())
print(per.get_gender())
print(per.get_friends())
# Out:
# 2
# ahmed
# sayed
# 24
# male
# [2, 3]

# %%
processData_obj=ProcssData("data.json")
# Out:
# id: 1
# firstName: Paul
# surname: Crowe
# age: 28
# gender: male
# friends: [2]
# id: 2
# firstName: Rob
# surname: Fitz
# age: 23
# gender: male
# friends: [1, 3]
# id: 3
# firstName: Ben
# surname: O'Carolan
# age: None
# gender: male
# friends: [2, 4, 5, 7]
# id: 4
# firstName: Victor
# surname:
# age: 28
# gender: male
# friends: [3]
# id: 5
# firstName: Peter
# surname: Mac
# age: 29
# gender: male
# friends: [3, 6, 11, 10, 7]
# id: 6
# firstName: John
# surname: Barry
# age: 18
# gender: male
# friends: [5]
# id: 7
# firstName: Sarah
# surname: Lane
# age: 30
# gender: female
# friends: [3, 5, 20, 12, 8]
# id: 8
# firstName: Susan
# surname: Downe
# age: 28
# gender: female
# friends: [7]
# id: 9
# firstName: Jack
# surname: Stam
# age: 28
# gender: male
# friends: [12]
# id: 10
# firstName: Amy
# surname: Lane
# age: 24
# gender: female
# friends: [5, 11]
# id: 11
# firstName: Sandra
# surname: Phelan
# age: 28
# gender: female
# friends: [5, 10, 19, 20]
# id: 12
# firstName: Laura
# surname: Murphy
# age: 33
# gender: female
# friends: [7, 9, 13, 20]
# id: 13
# firstName: Lisa
# surname: Daly
# age: 28
# gender: female
# friends: [12, 14, 20]
# id: 14
# firstName: Mark
# surname: Johnson
# age: 28
# gender: male
# friends: [13, 15]
# id: 15
# firstName: Seamus
# surname: Crowe
# age: 24
# gender: male
# friends: [14]
# id: 16
# firstName: Daren
# surname: Slater
# age: 28
# gender: male
# friends: [18, 20]
# id: 17
# firstName: Dara
# surname: Zoltan
# age: 48
# gender: male
# friends: [18, 20]
# id: 18
# firstName: Marie
# surname: D
# age: 28
# gender: female
# friends: [17]
# id: 19
# firstName: Catriona
# surname: Long
# age: 28
# gender: female
# friends: [11, 20]
# id: 20
# firstName: Katy
# surname: Couch
# age: 28
# gender: female
# friends: [7, 11, 12, 13, 16, 17, 19]
# {1: <__main__.Person object at 0x000000AD68DF3940>, 2: <__main__.Person object at 0x000000AD68DF3B00>, 3: <__main__.Person object at 0x000000AD68DF5198>, 4: <__main__.Person object at 0x000000AD68DF5748>, 5: <__main__.Person object at 0x000000AD68DF5CF8>, 6: <__main__.Person object at 0x000000AD68DD7358>, 7: <__main__.Person object at 0x000000AD68DD7940>, 8: <__main__.Person object at 0x000000AD68DD7F60>, 9: <__main__.Person object at 0x000000AD68DDF588>, 10: <__main__.Person object at 0x000000AD68DDFBA8>, 11: <__main__.Person object at 0x000000AD68DE41D0>, 12: <__main__.Person object at 0x000000AD68DE4780>, 13: <__main__.Person object at 0x000000AD68DE4D30>, 14: <__main__.Person object at 0x000000AD68DF1320>, 15: <__main__.Person object at 0x000000AD68DF1940>, 16: <__main__.Person object at 0x000000AD68DF1F28>, 17: <__main__.Person object at 0x000000AD68DED550>, 18: <__main__.Person object at 0x000000AD68DEDB00>, 19: <__main__.Person object at 0x000000AD68E0A128>, 20: <__main__.Person object at 0x000000AD68E0A710>}

# %%
print(processData_obj.get_direct_friends(2))
# Out:
# direct_friends of friend( 2 )= [1, 3]
# [1, 3]

# %%
friend_obj=processData_obj.get_person_from_id(3)
print(friend_obj.get_surname())
# Out:
# O'Carolan

# %%
friendsOfFriends_list=processData_obj.get_friends_of_friends(20)
print("friendsOfFriends_list:",friendsOfFriends_list)
# Out:
# direct_friends of friend( 20 )= [7, 11, 12, 13, 16, 17, 19]
# for friend id: 7
# direct_friends of friend( 7 )= [3, 5, 20, 12, 8]
# friends of direct friend ids: [3, 5, 20, 12, 8]
# ============
# for friend id: 11
# direct_friends of friend( 11 )= [5, 10, 19, 20]
# friends of direct friend ids: [5, 10, 19, 20]
# ============
# for friend id: 12
# direct_friends of friend( 12 )= [7, 9, 13, 20]
# friends of direct friend ids: [7, 9, 13, 20]
# ============
# for friend id: 13
# direct_friends of friend( 13 )= [12, 14, 20]
# friends of direct friend ids: [12, 14, 20]
# ============
# for friend id: 16
# direct_friends of friend( 16 )= [18, 20]
# friends of direct friend ids: [18, 20]
# ============
# for friend id: 17
# direct_friends of friend( 17 )= [18, 20]
# friends of direct friend ids: [18, 20]
# ============
# for friend id: 19
# direct_friends of friend( 19 )= [11, 20]
# friends of direct friend ids: [11, 20]
# ============
# friendsOfFriends before remove repeated: [3, 5, 20, 12, 8, 5, 10, 19, 20, 7, 9, 13, 20, 12, 14, 20, 18, 20, 18, 20, 11, 20]
# friendsOfFriends_list: [3, 5, 20, 12, 8, 10, 19, 7, 9, 13, 14, 18, 11]

# %%
suggestFriends_list=processData_obj.get_suggested_friends(20)
print("suggestFriends_list:",suggestFriends_list)
# Out:
# direct_friends of friend( 20 )= [7, 11, 12, 13, 16, 17, 19]
# for direct friend id: 7
# direct_friends of friend( 7 )= [3, 5, 20, 12, 8]
# friends_of_direct_friend_id: [3, 5, 20, 12, 8]
# for direct friend id: 11
# direct_friends of friend( 11 )= [5, 10, 19, 20]
# friends_of_direct_friend_id: [5, 10, 19, 20]
# for direct friend id: 12
# direct_friends of friend( 12 )= [7, 9, 13, 20]
# friends_of_direct_friend_id: [7, 9, 13, 20]
# for direct friend id: 13
# direct_friends of friend( 13 )= [12, 14, 20]
# friends_of_direct_friend_id: [12, 14, 20]
# for direct friend id: 16
# direct_friends of friend( 16 )= [18, 20]
# friends_of_direct_friend_id: [18, 20]
# for direct friend id: 17
# direct_friends of friend( 17 )= [18, 20]
# friends_of_direct_friend_id: [18, 20]
# for direct friend id: 19
# direct_friends of friend( 19 )= [11, 20]
# friends_of_direct_friend_id: [11, 20]
# ccountRepeatedId= [0, 0, 0, 1, 0, 2, 0, 1, 1, 1, 1, 1, 2, 1, 1, 0, 0, 0, 2, 1, 7]
# suggestFriends_list: [5, 18]

# %%
for ID in suggestFriends_list:
    print(processData_obj.hashTable[ID].get_firstName())
# Out:
# Peter
# Marie

# %%
print(processData_obj.hashTable[2].get_id())
print(processData_obj.hashTable[2].get_firstName())
print(processData_obj.hashTable[2].get_surname())
print(processData_obj.hashTable[2].get_age())
print(processData_obj.hashTable[2].get_gender())
print(processData_obj.hashTable[2].get_friends())
# Out:
# 2
# Rob
# Fitz
# 23
# male
# [1, 3]

# %%
processData_obj=ProcssData("data.json")
# Out:
# id: 1
# firstName: Paul
# surname: Crowe
# age: 28
# gender: male
# friends: [2]
# id: 2
# firstName: Rob
# surname: Fitz
# age: 23
# gender: male
# friends: [1, 3]
# id: 3
# firstName: Ben
# surname: O'Carolan
# age: None
# gender: male
# friends: [2, 4, 5, 7]
# id: 4
# firstName: Victor
# surname:
# age: 28
# gender: male
# friends: [3]
# id: 5
# firstName: Peter
# surname: Mac
# age: 29
# gender: male
# friends: [3, 6, 11, 10, 7]
# id: 6
# firstName: John
# surname: Barry
# age: 18
# gender: male
# friends: [5]
# id: 7
# firstName: Sarah
# surname: Lane
# age: 30
# gender: female
# friends: [3, 5, 20, 12, 8]
# id: 8
# firstName: Susan
# surname: Downe
# age: 28
# gender: female
# friends: [7]
# id: 9
# firstName: Jack
# surname: Stam
# age: 28
# gender: male
# friends: [12]
# id: 10
# firstName: Amy
# surname: Lane
# age: 24
# gender: female
# friends: [5, 11]
# id: 11
# firstName: Sandra
# surname: Phelan
# age: 28
# gender: female
# friends: [5, 10, 19, 20]
# id: 12
# firstName: Laura
# surname: Murphy
# age: 33
# gender: female
# friends: [7, 9, 13, 20]
# id: 13
# firstName: Lisa
# surname: Daly
# age: 28
# gender: female
# friends: [12, 14, 20]
# id: 14
# firstName: Mark
# surname: Johnson
# age: 28
# gender: male
# friends: [13, 15]
# id: 15
# firstName: Seamus
# surname: Crowe
# age: 24
# gender: male
# friends: [14]
# id: 16
# firstName: Daren
# surname: Slater
# age: 28
# gender: male
# friends: [18, 20]
# id: 17
# firstName: Dara
# surname: Zoltan
# age: 48
# gender: male
# friends: [18, 20]
# id: 18
# firstName: Marie
# surname: D
# age: 28
# gender: female
# friends: [17]
# id: 19
# firstName: Catriona
# surname: Long
# age: 28
# gender: female
# friends: [11, 20]
# id: 20
# firstName: Katy
# surname: Couch
# age: 28
# gender: female
# friends: [7, 11, 12, 13, 16, 17, 19]
# {1: <__main__.Person object at 0x000000AD68DF12B0>, 2: <__main__.Person object at 0x000000AD68DE4D68>, 3: <__main__.Person object at 0x000000AD68DE44A8>, 4: <__main__.Person object at 0x000000AD68DDFF98>, 5: <__main__.Person object at 0x000000AD68DDF828>, 6: <__main__.Person object at 0x000000AD68DDF128>, 7: <__main__.Person object at 0x000000AD68DD7BA8>, 8: <__main__.Person object at 0x000000AD68DED0F0>, 9: <__main__.Person object at 0x000000AD68DD73C8>, 10: <__main__.Person object at 0x000000AD68DF5E10>, 11: <__main__.Person object at 0x000000AD68DF5710>, 12: <__main__.Person object at 0x000000AD68DF32B0>, 13: <__main__.Person object at 0x000000AD68DF3BA8>, 14: <__main__.Person object at 0x000000AD68DF3668>, 15: <__main__.Person object at 0x000000AD68DC3BE0>, 16: <__main__.Person object at 0x000000AD68E0A5F8>, 17: <__main__.Person object at 0x000000AD68E0A7F0>, 18: <__main__.Person object at 0x000000AD68E0AE10>, 19: <__main__.Person object at 0x000000AD68DDD438>, 20: <__main__.Person object at 0x000000AD68DDD9E8>}

# %%
class SocialAppGUI():
    def __init__(self,window,procesDataObj):
        self.processDataObj=procesDataObj
        
        ##specify window 
        self.window = window
        self.window.title("Social media app")
        self.window.geometry('450x475')
        
        ##specify input label frame 
        self.inputLabelFrame=LabelFrame(self.window, text="Choose user and type of friends")
        self.inputLabelFrame.grid(column=0, row=0)
        ##specify choose user label
        self.chooseUserLbl = Label(self.inputLabelFrame, text="Choose user id:")
        self.chooseUserLbl.grid(column=0, row=0)
        ##specify combobox ids
        ComboboxValues=[]
        for i in range(1,self.processDataObj.get_length_of_hashTable()+1):
            ComboboxValues.append(i)
        self.comboIDs = Combobox(self.inputLabelFrame,state="readonly",values=ComboboxValues,width=10)
        self.comboIDs.grid(column=1, row=0)
        self.comboIDs.current(0)
        ##specify choose type of friends label
        lbl = Label(self.inputLabelFrame, text="Choose type of friend to show:")
        lbl.grid(column=0, row=1)
        ##spcify direct friend check button
        self.directFriendVar=IntVar()
        self.directFriendCheckbutton=Checkbutton(self.inputLabelFrame,text="Direct friends",variable=self.directFriendVar)
        self.directFriendCheckbutton.grid(column=0,row=2)
        ##spcify friends of friends check button
        self.friendsOfFriendVar=IntVar()
        self.friendsOfFriendCheckbutton=Checkbutton(self.inputLabelFrame,text="Friends of friends",variable=self.friendsOfFriendVar)
        self.friendsOfFriendCheckbutton.grid(column=1,row=2)
        self.padLbl1 = Label(self.inputLabelFrame, text=" ")  ##pad label
        self.padLbl1.grid(column=2, row=2)
        ##spcify suggested friend check button
        self.suggestedFriendVar=IntVar()
        self.suggestedFriendCheckbutton=Checkbutton(self.inputLabelFrame,text="Suggested friends",variable=self.suggestedFriendVar)
        self.suggestedFriendCheckbutton.grid(column=3,row=2)
        self.padLbl2 = Label(self.inputLabelFrame, text="")
        self.padLbl2.grid(column=4,row=2)
        
        ##sepeicify output label frame
        self.outputLabelframe=LabelFrame(self.window, text="Output")
        self.outputLabelframe.grid(column=0, row=2)
        ##specify direct friend label and scrolled text
        self.directFriendLbl = Label(self.outputLabelframe, text="Direct friends")
        self.directFriendLbl.grid(column=0, row=0)
        self.directFriendsScroll = scrolledtext.ScrolledText(self.outputLabelframe,width=20,height=15)
        self.directFriendsScroll.grid(column=0,row=1)
        self.directFriendsScroll.configure(state='disabled')
        ##specify friends of friend label and scrolled text
        self.friendsOfFriendLbl = Label(self.outputLabelframe, text="Friends of friends")
        self.friendsOfFriendLbl.grid(column=1, row=0)
        self.friendsOfFriendsScroll = scrolledtext.ScrolledText(self.outputLabelframe,width=20,height=15)
        self.friendsOfFriendsScroll.grid(column=1,row=1)
        self.friendsOfFriendsScroll.configure(state='disabled')
        ##specify sugggested friend label and scrolled text
        self.suggestedFriendLbl = Label(self.outputLabelframe, text="Suggested friends")
        self.suggestedFriendLbl.grid(column=2, row=0)
        self.suggestedFriendsScroll = scrolledtext.ScrolledText(self.outputLabelframe,width=20,height=15)
        self.suggestedFriendsScroll.grid(column=2,row=1)
        self.suggestedFriendsScroll.configure(state='disabled')
        
        ##sepecify get data button 
        self.padlbl3 = Label(self.inputLabelFrame, text="")
        self.padlbl3.grid(column=1, row=3)
        self.getDataBtn = Button(self.inputLabelFrame, text="Get data", bg="green", fg="white", command=self.clicked,width=15)
        self.getDataBtn.grid(column=1, row=4)

        ##specify quit button 
        self.padlbl4 = Label(self.window, text=" ")
        self.padlbl4.grid(column=0, row=3)
        self.quitBtn = Button(self.window, text="Quit", bg="red", fg="white", command=self.close_window,width=15)
        self.quitBtn.grid(column=0, row=4)
        
    def clicked(self):
        chosenID=int(self.comboIDs.get())
        if(self.directFriendVar.get()==1):
            self.directFriendsScroll.configure(state='normal')
            self.directFriendsScroll.delete('1.0', END)
            directFriends=processData_obj.get_direct_friends(chosenID)
            if(len(directFriends)>0):
                text=""
                for i,ID in enumerate(directFriends):
                    personObj=self.processDataObj.get_person_from_id(ID)
                    text+="id:"+str(ID)+"\n"+"FirstName:"+personObj.get_firstName()+"\n"+
                    "surname:"+personObj.get_surname()+"\n"
                    if(i<(len(directFriends)-1)): ## to prevent printing line after last person
                        text+="--------------"+"\n"
                self.directFriendsScroll.insert(INSERT,text)
            else:
                self.directFriendsScroll.insert(INSERT,"None")
            self.directFriendsScroll.configure(state='disabled')
        else:
            self.directFriendsScroll.configure(state='normal')
            self.directFriendsScroll.delete('1.0', END)
            self.directFriendsScroll.configure(state='disabled')


        if(self.friendsOfFriendVar.get()==1):
            self.friendsOfFriendsScroll.configure(state='normal')
            self.friendsOfFriendsScroll.delete('1.0', END)
            friendsOfFriends=processData_obj.get_friends_of_friends(chosenID)
            if(len(friendsOfFriends)>0):
                text=""
                for i,ID in enumerate(friendsOfFriends):
                    personObj=self.processDataObj.get_person_from_id(ID)
                    text+="id:"+str(ID)+"\n"+"FirstName:"+personObj.get_firstName()+"\n"+
                    "surname:"+personObj.get_surname()+"\n"
                    if(i<(len(friendsOfFriends)-1)): ## to prevent printing line after last person
                        text+="--------------"+"\n"
                self.friendsOfFriendsScroll.insert(INSERT,text)
            else:
                self.friendsOfFriendsScroll.insert(INSERT,"None")
            self.friendsOfFriendsScroll.configure(state='disabled')
        else:
            self.friendsOfFriendsScroll.configure(state='normal')
            self.friendsOfFriendsScroll.delete('1.0', END)
            self.friendsOfFriendsScroll.configure(state='disabled')

        if(self.suggestedFriendVar.get()==1):
            self.suggestedFriendsScroll.configure(state='normal')
            self.suggestedFriendsScroll.delete('1.0', END)
            suggestedFriends=processData_obj.get_suggested_friends(chosenID)
            if(len(suggestedFriends)>0):
                text=""
                for i,ID in enumerate(suggestedFriends):
                    personObj=self.processDataObj.get_person_from_id(ID)
                    text+="id:"+str(ID)+"\n"+"FirstName:"+personObj.get_firstName()+"\n"+
                    "surname:"+personObj.get_surname()+"\n"
                    if(i<(len(suggestedFriends)-1)): ## to prevent printing line after last person
                        text+="--------------"+"\n"
                self.suggestedFriendsScroll.insert(INSERT,text)
            else:
                self.suggestedFriendsScroll.insert(INSERT,"None")
            self.suggestedFriendsScroll.configure(state='disabled')
        else:
            self.suggestedFriendsScroll.configure(state='normal')
            self.suggestedFriendsScroll.delete('1.0', END)
            self.suggestedFriendsScroll.configure(state='disabled')
    
    def close_window(self):
        self.window.destroy()

# %%
processDataObj=ProcssData("data.json")
if(not(processDataObj.get_length_of_hashTable()==0)):#file exist 
    window = Tk()
    a=SocialAppGUI(window,processDataObj)
    window.mainloop()
# Out:
# id: 1
# firstName: Paul
# surname: Crowe
# age: 28
# gender: male
# friends: [2]
# id: 2
# firstName: Rob
# surname: Fitz
# age: 23
# gender: male
# friends: [1, 3]
# id: 3
# firstName: Ben
# surname: O'Carolan
# age: None
# gender: male
# friends: [2, 4, 5, 7]
# id: 4
# firstName: Victor
# surname:
# age: 28
# gender: male
# friends: [3]
# id: 5
# firstName: Peter
# surname: Mac
# age: 29
# gender: male
# friends: [3, 6, 11, 10, 7]
# id: 6
# firstName: John
# surname: Barry
# age: 18
# gender: male
# friends: [5]
# id: 7
# firstName: Sarah
# surname: Lane
# age: 30
# gender: female
# friends: [3, 5, 20, 12, 8]
# id: 8
# firstName: Susan
# surname: Downe
# age: 28
# gender: female
# friends: [7]
# id: 9
# firstName: Jack
# surname: Stam
# age: 28
# gender: male
# friends: [12]
# id: 10
# firstName: Amy
# surname: Lane
# age: 24
# gender: female
# friends: [5, 11]
# id: 11
# firstName: Sandra
# surname: Phelan
# age: 28
# gender: female
# friends: [5, 10, 19, 20]
# id: 12
# firstName: Laura
# surname: Murphy
# age: 33
# gender: female
# friends: [7, 9, 13, 20]
# id: 13
# firstName: Lisa
# surname: Daly
# age: 28
# gender: female
# friends: [12, 14, 20]
# id: 14
# firstName: Mark
# surname: Johnson
# age: 28
# gender: male
# friends: [13, 15]
# id: 15
# firstName: Seamus
# surname: Crowe
# age: 24
# gender: male
# friends: [14]
# id: 16
# firstName: Daren
# surname: Slater
# age: 28
# gender: male
# friends: [18, 20]
# id: 17
# firstName: Dara
# surname: Zoltan
# age: 48
# gender: male
# friends: [18, 20]
# id: 18
# firstName: Marie
# surname: D
# age: 28
# gender: female
# friends: [17]
# id: 19
# firstName: Catriona
# surname: Long
# age: 28
# gender: female
# friends: [11, 20]
# id: 20
# firstName: Katy
# surname: Couch
# age: 28
# gender: female
# friends: [7, 11, 12, 13, 16, 17, 19]
# {1: <__main__.Person object at 0x000000AD68DEDBA8>, 2: <__main__.Person object at 0x000000AD68ED1390>, 3: <__main__.Person object at 0x000000AD68ED1B38>, 4: <__main__.Person object at 0x000000AD68DF1978>, 5: <__main__.Person object at 0x000000AD68DF12E8>, 6: <__main__.Person object at 0x000000AD68CBB1D0>, 7: <__main__.Person object at 0x000000AD68EC66D8>, 8: <__main__.Person object at 0x000000AD68EC6E10>, 9: <__main__.Person object at 0x000000AD68DCF780>, 10: <__main__.Person object at 0x000000AD68DCF0F0>, 11: <__main__.Person object at 0x000000AD68CB4D30>, 12: <__main__.Person object at 0x000000AD68DDFC88>, 13: <__main__.Person object at 0x000000AD68DDD6D8>, 14: <__main__.Person object at 0x000000AD68DD7588>, 15: <__main__.Person object at 0x000000AD68DD7320>, 16: <__main__.Person object at 0x000000AD68E0AE10>, 17: <__main__.Person object at 0x000000AD68E0A400>, 18: <__main__.Person object at 0x000000AD68E58438>, 19: <__main__.Person object at 0x000000AD68E58550>, 20: <__main__.Person object at 0x000000AD68E589B0>}
# direct_friends of friend( 20 )= [7, 11, 12, 13, 16, 17, 19]
# direct_friends of friend( 20 )= [7, 11, 12, 13, 16, 17, 19]
# for friend id: 7
# direct_friends of friend( 7 )= [3, 5, 20, 12, 8]
# friends of direct friend ids: [3, 5, 20, 12, 8]
# ============
# for friend id: 11
# direct_friends of friend( 11 )= [5, 10, 19, 20]
# friends of direct friend ids: [5, 10, 19, 20]
# ============
# for friend id: 12
# direct_friends of friend( 12 )= [7, 9, 13, 20]
# friends of direct friend ids: [7, 9, 13, 20]
# ============
# for friend id: 13
# direct_friends of friend( 13 )= [12, 14, 20]
# friends of direct friend ids: [12, 14, 20]
# ============
# for friend id: 16
# direct_friends of friend( 16 )= [18, 20]
# friends of direct friend ids: [18, 20]
# ============
# for friend id: 17
# direct_friends of friend( 17 )= [18, 20]
# friends of direct friend ids: [18, 20]
# ============
# for friend id: 19
# direct_friends of friend( 19 )= [11, 20]
# friends of direct friend ids: [11, 20]
# ============
# friendsOfFriends before remove repeated: [3, 5, 20, 12, 8, 5, 10, 19, 20, 7, 9, 13, 20, 12, 14, 20, 18, 20, 18, 20, 11, 20]
# direct_friends of friend( 20 )= [7, 11, 12, 13, 16, 17, 19]
# for direct friend id: 7
# direct_friends of friend( 7 )= [3, 5, 20, 12, 8]
# friends_of_direct_friend_id: [3, 5, 20, 12, 8]
# for direct friend id: 11
# direct_friends of friend( 11 )= [5, 10, 19, 20]
# friends_of_direct_friend_id: [5, 10, 19, 20]
# for direct friend id: 12
# direct_friends of friend( 12 )= [7, 9, 13, 20]
# friends_of_direct_friend_id: [7, 9, 13, 20]
# for direct friend id: 13
# direct_friends of friend( 13 )= [12, 14, 20]
# friends_of_direct_friend_id: [12, 14, 20]
# for direct friend id: 16
# direct_friends of friend( 16 )= [18, 20]
# friends_of_direct_friend_id: [18, 20]
# for direct friend id: 17
# direct_friends of friend( 17 )= [18, 20]
# friends_of_direct_friend_id: [18, 20]
# for direct friend id: 19
# direct_friends of friend( 19 )= [11, 20]
# friends_of_direct_friend_id: [11, 20]
# ccountRepeatedId= [0, 0, 0, 1, 0, 2, 0, 1, 1, 1, 1, 1, 2, 1, 1, 0, 0, 0, 2, 1, 7]

# %%
window = Tk()
window.title("social media app")
window.geometry('450x450')

labelframe=LabelFrame(window, text="Choose user and type of friends")
labelframe.grid(column=0, row=0)

lbl = Label(labelframe, text="Choose user id:")
lbl.grid(column=0, row=0)
ComboboxValues=[]
for i in range(1,21):
    ComboboxValues.append(i)
comboIDs = Combobox(labelframe,state="readonly",values=ComboboxValues,width=10)
comboIDs.grid(column=1, row=0)
comboIDs.current(0)


lbl = Label(labelframe, text="Choose type of friend to show:")
lbl.grid(column=0, row=1)
var1 = IntVar()
checkbutton1=Checkbutton(labelframe,text="Direct friends",variable=var1)
checkbutton1.grid(column=0,row=2)

var2 = IntVar()
checkbutton2=Checkbutton(labelframe, text="Friends of friends",variable=var2)
checkbutton2.grid(column=1,row=2)
lbl = Label(labelframe, text=" ")
lbl.grid(column=2, row=2)

var3 = IntVar()
checkbutton3=Checkbutton(labelframe, text="Suggested friends",variable=var3)
checkbutton3.grid(column=3,row=2)
lbl = Label(labelframe, text="")
lbl.grid(column=4,row=2)

outputLabelframe=LabelFrame(window, text="Output")
outputLabelframe.grid(column=0, row=2)

lbl = Label(outputLabelframe, text="Direct friends")
lbl.grid(column=0, row=0)
directFriendsScroll = scrolledtext.ScrolledText(outputLabelframe,width=15,height=15)
directFriendsScroll.grid(column=0,row=1)
directFriendsScroll.configure(state='disabled')

lbl = Label(outputLabelframe, text="Friends of friends")
lbl.grid(column=1, row=0)
friendsOfFriendsScroll = scrolledtext.ScrolledText(outputLabelframe,width=15,height=15)
friendsOfFriendsScroll.grid(column=1,row=1)
friendsOfFriendsScroll.configure(state='disabled')

lbl = Label(outputLabelframe, text="Suggested friends")
lbl.grid(column=2, row=0)
suggestedFriendsScroll = scrolledtext.ScrolledText(outputLabelframe,width=15,height=15)
suggestedFriendsScroll.grid(column=2,row=1)
suggestedFriendsScroll.configure(state='disabled')


def clicked():
    chosenID=int(comboIDs.get())
    print("var1 state:",var1.get())
    print(type(var1.get()))
    if(var1.get()==1):
        directFriendsScroll.configure(state='normal')
        directFriendsScroll.delete('1.0', END)
        directFriends=processData_obj.get_direct_friends(chosenID)
        if(len(directFriends)>0):
            directFriendsScroll.insert(INSERT, directFriends)
        else:
            directFriendsScroll.insert(INSERT,"None")
        directFriendsScroll.configure(state='disabled')
    else:
        directFriendsScroll.configure(state='normal')
        directFriendsScroll.delete('1.0', END)
        directFriendsScroll.configure(state='disabled')
        
        
    
    print("var2 state:",var2.get())
    if(var2.get()==1):
        friendsOfFriendsScroll.configure(state='normal')
        friendsOfFriendsScroll.delete('1.0', END)
        friendsOfFriends=processData_obj.get_friends_of_friends(chosenID)
        if(len(friendsOfFriends)>0):
            friendsOfFriendsScroll.insert(INSERT, friendsOfFriends)
        else:
            friendsOfFriendsScroll.insert(INSERT,"None")
        friendsOfFriendsScroll.configure(state='disabled')
    else:
        friendsOfFriendsScroll.configure(state='normal')
        friendsOfFriendsScroll.delete('1.0', END)
        friendsOfFriendsScroll.configure(state='disabled')
        
    
    print("var3 state:",var3.get())
    if(var3.get()==1):
        suggestedFriendsScroll.configure(state='normal')
        suggestedFriendsScroll.delete('1.0', END)
        suggestedFriends=processData_obj.get_suggested_friends(chosenID)
        if(len(suggestedFriends)>0):
            suggestedFriendsScroll.insert(INSERT, suggestedFriends)
        else:
            suggestedFriendsScroll.insert(INSERT,"None")
        suggestedFriendsScroll.configure(state='disabled')
    else:
        suggestedFriendsScroll.configure(state='normal')
        suggestedFriendsScroll.delete('1.0', END)
        suggestedFriendsScroll.configure(state='disabled')
        
        
    print("user id:",chosenID)
    print(type(chosenID))
    

getDataBtn = Button(labelframe, text="Get data", bg="green", fg="white", command=clicked)
getDataBtn.grid(column=1, row=3)
lbl = Label(window, text=" ")
lbl.grid(column=0, row=3)
def close_window(): 
    window.destroy()

quitBtn = Button(window, text="Quit", bg="red", fg="white", command=close_window,width=15)
quitBtn.grid(column=0, row=4)



window.mainloop()
